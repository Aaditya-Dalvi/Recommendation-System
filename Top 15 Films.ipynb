# %%
import pandas as pd

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')
print(movies.columns)
print(credits.columns)
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')
# Index(['movie_id', 'title', 'cast', 'crew'], dtype='object')

# %%
df = movies.merge(credits, on = 'title')
df.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
# ...

# %%
popular_movies = df[df['vote_count'] >=5000].sort_values(by='vote_average',ascending=False)[['id','title','vote_average','vote_count','runtime','release_date']][:15]

# %%
popular_movies.reset_index(drop=True, inplace=True)
popular_movies
# Out:
#         id                                              title  vote_average  \
# 0      278                           The Shawshank Redemption           8.5
# 1      238                                      The Godfather           8.4
# 2      680                                       Pulp Fiction           8.3
# 3      550                                         Fight Club           8.3
# 4      155                                    The Dark Knight           8.2
# 5     1891                            The Empire Strikes Back           8.2
# 6       13                                       Forrest Gump           8.2
# 7       11                                          Star Wars           8.1
# 8      122      The Lord of the Rings: The Return of the King           8.1
# 9      807                                              Se7en           8.1
# 10   27205                                          Inception           8.1
# ...

# %%
dates = popular_movies['release_date'].str.split('-')
years = []

for date in dates:
    years.append(date[0])
popular_movies['release_date']=years 
popular_movies
# Out:
#         id                                              title  vote_average  \
# 0      278                           The Shawshank Redemption           8.5
# 1      238                                      The Godfather           8.4
# 2      680                                       Pulp Fiction           8.3
# 3      550                                         Fight Club           8.3
# 4      155                                    The Dark Knight           8.2
# 5     1891                            The Empire Strikes Back           8.2
# 6       13                                       Forrest Gump           8.2
# 7       11                                          Star Wars           8.1
# 8      122      The Lord of the Rings: The Return of the King           8.1
# 9      807                                              Se7en           8.1
# 10   27205                                          Inception           8.1
# ...

# %%
# import requests
# ids = list(popular_movies['id'].values)
# images=[]
# for id in ids: 
#     response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key=47f5dabb1b608b91fe3ef3ad90ffef57&language=en-US'.format(id))
#     data = response.json()
#     images.append("https://image.tmdb.org/t/p/w500/" + data['poster_path'])

# %%
import pickle
pickle.dump(popular_movies,open('models/popular_movies.pkl','wb'))
